# %%
# %run train.py --data ./ --save ./
# Out:
# ...
# 100.0%
# Extracting ./cifar-100-python.tar.gz to ./
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/Projects/UniPassau/safe ai/temperature_scaling/train.py:254
#     242 if __name__ == '__main__':
#     243     """
#     244     Train a 40-layer DenseNet-BC on CIFAR-100
#     245
#    (...)
#     252         --seed (int) - manually set the random seed (default None)
#     253     """
# --> 254     fire.Fire(train)
#
# File ~/Projects/UniPassau/safe ai/temperature_scaling/venv/lib/python3.9/site-packages/fire/core.py:141, in Fire(component, command, name)
#     138   context.update(caller_globals)
#     139   context.update(caller_locals)
# --> 141 component_trace = _Fire(component, args, parsed_flag_args, context, name)
#     143 if component_trace.HasError():
#     144   _DisplayError(component_trace)
#
# ...
